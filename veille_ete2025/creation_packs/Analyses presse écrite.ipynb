# %%
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 200)
from collections import Counter

# %% [markdown]
# ## Load data

# %% [markdown]
# ### Charger les données

# %%
# Load subjects
subjects = pd.read_excel('Articles_excel_vf_12_06.xlsx', sheet_name="Subjects", header=2)
# Garder les 3 premières colonnes
subjects = subjects.iloc[:, :3]

# Renommer la première colonne
subjects = subjects.rename(columns={subjects.columns[0]: "code"})
subjects.head()
# Out:
#      code                       Descriptor  \
# 0    MCAT  Commodity/Financial Market News
# 1     M14                Commodity Markets
# 2    M141   Agricultural Commodity Markets
# 3   MLUMB          Forest Products Markets
# 4  MFRUIT                    Fruit Markets
#
#                                          Description
# 0  Markets for trading in financial instruments o...
# 1  Market data, such as daily quotes and trading ...
# 2  Market data, such as daily quotes and trading ...
# 3  Market data, such as daily quotes and trading ...
# 4  Market data, such as daily quotes and trading ...

# %%
df = pd.read_excel('Articles_excel_vf_12_06.xlsx')
df.head()
# Out:
#   source_name                                              title  \
# 0  L'Humanité                                    L’œil de Bobika
# 1  L'Humanité  Claude Ven est décédé le 4 avril à l’âge de 63...
# 2  L'Humanité                                    L’œil de Bobika
# 3  L'Humanité                                      L’œil de Gros
# 4  Libération  Réponse fraternelle à Dominique de Villepin : ...
#
#   publication_date     subject_codes word_count                Dossier  \
# 0       2025-04-14       ,ncat,nhoc,          4  articles_pdf_national
# 1       2025-04-15       ,gcat,gjob,        400  articles_pdf_national
# 2       2025-04-15       ,ncat,nhoc,          4  articles_pdf_national
# 3       2025-04-16       ,ncat,nhoc,          4  articles_pdf_national
# 4       2025-04-15  ,gcat,gpir,gpol,       1180  articles_pdf_national
#
#                   nom_fichier                          publisher_name  \
# 0   LHumanité_1744570903000_0  Société Nouvelle du Journal l'Humanité
# 1   LHumanité_1744657577000_1  Société Nouvelle du Journal l'Humanité
# 2   LHumanité_1744657578000_2  Société Nouvelle du Journal l'Humanité
# 3   LHumanité_1744743866000_3  Société Nouvelle du Journal l'Humanité
# 4  Libération_1744806835000_4                              Libération
#
#   source_code industry_codes section document_type         region_of_origin  \
# 0       HUMAN            NaN     NaN       article      EUR FRA MEDZ WEURZ
# 1       HUMAN            NaN     NaN       article      EUR FRA MEDZ WEURZ
# 2       HUMAN            NaN     NaN       article      EUR FRA MEDZ WEURZ
# 3       HUMAN            NaN     NaN       article      EUR FRA MEDZ WEURZ
# 4      LIBERA            NaN     NaN       article  AFRICA MEDZ MOROC NAFR
#
#                         region_codes                         an  \
# 0         ,eecz,eurz,fra,medz,weurz,  HUMAN00020250413el4e00002
# 1  ,britty,eecz,eurz,fra,medz,weurz,  HUMAN00020250414el4f000rx
# 2         ,eecz,eurz,fra,medz,weurz,  HUMAN00020250414el4f000s9
# 3         ,eecz,eurz,fra,medz,weurz,  HUMAN00020250415el4g000m9
# 4         ,eecz,eurz,fra,medz,weurz,  LIBERA0020250416el4f00001
#
#    ingestion_datetime publication_datetime   modification_date  \
# 0 2025-04-13 19:01:43           2025-04-14 2025-04-14 08:52:40
# 1 2025-04-14 19:06:17           2025-04-15 2025-04-15 07:31:12
# 2 2025-04-14 19:06:18           2025-04-15 2025-04-15 07:33:00
# 3 2025-04-15 19:04:26           2025-04-16 2025-04-16 07:30:33
# 4 2025-04-16 12:33:55           2025-04-15 2025-04-17 07:29:29
#
#   modification_datetime                                       copyright  \
# 0   2025-04-13 19:01:43  Copyright 2025 l'Humanité All Rights Reserved
# 1   2025-04-14 19:06:17  Copyright 2025 l'Humanité All Rights Reserved
# 2   2025-04-14 19:06:18  Copyright 2025 l'Humanité All Rights Reserved
# 3   2025-04-15 19:04:26  Copyright 2025 l'Humanité All Rights Reserved
# 4   2025-04-16 12:33:55                      Copyright 2025 Libération
#
#   language_code dateline byline
# 0            fr      NaN    NaN
# 1            fr      NaN    NaN
# 2            fr      NaN    NaN
# 3            fr      NaN    NaN
# 4            fr      NaN    NaN

# %% [markdown]
# ### Créer le mapping des sujets

# %%
# Construction du dictionnaire de correspondance (clé = code en minuscules)
mapping = dict(zip(subjects["code"].str.lower(), subjects.iloc[:, 1]))

# %%
mapping
# Out:
# {'mcat': 'Commodity/Financial Market News',
#  'm14': 'Commodity Markets',
#  'm141': 'Agricultural Commodity Markets',
#  'mlumb': 'Forest Products Markets',
#  'mfruit': 'Fruit Markets',
#  'mgroil': 'Grains/Edible Oils Markets',
#  'medoil': 'Edible Oils Markets',
#  'mveoil': 'Vegetable Oil Markets',
#  'mgrain': 'Grain Markets',
#  'mcorn': 'Corn Markets',
#  'mrice': 'Rice Markets',
#  'mwheat': 'Wheat Markets',
#  'moilsd': 'Oilseed Markets',
#  'mgrfds': 'Livestock Meals/Feeds Markets',
#  'mlvstk': 'Livestock/Meat Markets',
#  'mcattl': 'Beef/Dairy Cattle Markets',
#  'mdair': 'Dairy Markets',
#  'mhogs': 'Pork/Pigs Markets',
#  'mpoult': 'Poultry/Eggs Markets',
#  'mwool': 'Wool Markets',
#  'mpulse': 'Pulse Markets',
#  'mbean': 'Beans Markets',
#  'mrubb': 'Rubber Markets',
#  'magric': 'Soft Commodity Markets',
#  'mcocoa': 'Cocoa Markets',
#  'mcoff': 'Coffee Markets',
#  'mcott': 'Cotton Markets',
#  'moranj': 'Orange Juice Markets',
#  'msugar': 'Sugar Markets',
#  'mspice': 'Spices Markets',
#  'm143': 'Energy Markets',
#  'mcoal': 'Coal Markets',
#  'mcroil': 'Crude Oil Markets',
#  'mcrntg': 'Crude Oil/Natural Gas Product Markets',
#  'mbnker': 'Bunker Fuel Markets',
#  'mjtful': 'Jet Fuel Markets',
#  'mlpg': 'Liquid Petroleum/Gas Markets',
#  'mmotfl': 'Motor Fuel Markets',
#  'mnapth': 'Naphtha Markets',
#  'mpetch': 'Petrochemicals Markets',
#  'mpoly': 'Polymers Markets',
#  'melec': 'Electricity Markets',
#  'mnatgs': 'Natural Gas Markets',
#  'm142': 'Metals Markets',
#  'mirono': 'Iron Ore Markets',
#  'mminmt': 'Minor Metals Markets',
#  'mnonfr': 'Non-ferrous Metals Markets',
#  'malum': 'Aluminium Markets',
#  'mcopp': 'Copper Markets',
#  'mlead': 'Lead Markets',
#  'mnickl': 'Nickel Markets',
#  'mtin': 'Tin Markets',
#  'mzinc': 'Zinc Markets',
#  'mpcsmt': 'Precious Metals Markets',
#  'm1421': 'Gold Markets',
#  'mplat': 'Platinum Metals Markets',
#  'msilv': 'Silver Markets',
#  'msteel': 'Steel Markets',
#  'm12': 'Debt/Bond Markets',
#  'mcpdbt': 'Corporate Debt/Bond Markets',
#  'mgvdbt': 'Government Debt/Bond Markets',
#  'mmuni': 'Municipal Debt/Bond Markets',
#  'mntdbt': 'National Government Debt/Bond Markets',
#  'm15': 'Derivatives Markets',
#  'mcuop': 'Currency Options Markets',
#  'msoptn': 'Stock Options Markets',
#  'mswap': 'Swap Markets',
#  'memiss': 'Emission Markets',
#  'm11': 'Equity Markets',
#  'm16': 'Fund Markets',
#  'm13': 'Money/Currency Markets',
#  'm132': 'Foreign Exchange Markets',
#  'mcryp': 'Cryptocurrency Markets',
#  'm131': 'Money Markets',
#  'mspotp': 'Spot Markets',
#  'ncat': 'Content Types',
#  'nabst': 'Abstracts',
#  'nadvtr': 'Advertorials/Sponsored Content',
#  'nadc': 'Advice',
#  'naigc': 'AI-Generated Content',
#  'nanl': 'Analyses',
#  'naudvl': 'Audio-visual Links',
#  'nblog': 'Blogs',
#  'ncal': 'Calendar of Events',
#  'nchr': 'Chronology',
#  'ncolu': 'Columns',
#  'nedc': 'Commentaries/Opinions',
#  'ncdig': 'Corporate Digests',
#  'ncopro': 'Country Profiles',
#  'npred': 'Economic Predictions/Forecasts',
#  'nwkah': 'Week Ahead Outlooks',
#  'nedi': 'Editorials',
#  'nfact': 'Factiva Filters',
#  'namt': 'All Market Talk',
#  'ndjmt': 'Dow Jones Market Talk',
#  'nfxmt': 'Foreign Exchange Market Talk',
#  'ncmac': 'Commodities Asset Class News',
#  'npda': 'DJ Exclusive Analysis - All',
#  'npcda': 'DJ Exclusive Analysis - Commodities',
#  'npenda': 'DJ Exclusive Analysis - Energy',
#  'npqda': 'DJ Exclusive Analysis - Equities',
#  'npfida': 'DJ Exclusive Analysis - Fixed Income',
#  'npfxda': 'DJ Exclusive Analysis - FX',
#  'npdn': 'DJ Exclusive News - All',
#  'npfidn': 'DJ Dominant News - Fixed Income',
#  'npcdn': 'DJ Exclusive News - Commodities',
#  'npendn': 'DJ Exclusive News - Energy',
#  'npqan': 'DJ Exclusive News - Equities',
#  'npfxdn': 'DJ Exclusive News - FX',
#  'nenac': 'Energy Asset Class News',
#  'neqac': 'Equities Asset Class News',
#  'nfiac': 'Fixed Income Asset Class News',
#  'nfxacb': 'Forex Asset Class Basic News',
#  'nfxacp': 'Forex Asset Class Premium News',
#  'nhrd': 'Heard on the Street',
#  'nlist': 'Headline Listings',
#  'nhoc': 'Headline-Only Content',
#  'nimage': 'Images',
#  'nitv': 'Interviews',
#  'niex': 'Interviews with Corporate Executives',
#  'nlet': 'Letters',
#  'nnam': 'News Agency Materials',
#  'nsum': 'News Digests',
#  'nobt': 'Obituaries',
#  'npag': 'Page One Stories',
#  'npeo': 'People Profiles',
#  'nartpr': 'Artist Profiles',
#  'npan': 'Personal Announcements',
#  'npress': 'Press Releases',
#  'nprpct': 'Prospectuses',
#  'nran': 'Rankings',
#  'nrvw': 'Reviews',
#  'gtrrw': 'Travel Reviews',
#  'nrgn': 'Routine General News',
#  'nadv': 'Advisories',
#  'ncap': 'Captions',
#  'ncont': 'Contest/Lottery Announcements',
#  'ghorsc': 'Horoscopes',
#  'grelis': 'Real Estate Listings',
#  'grcps': 'Recipes',
#  'gtrep': 'Routine Traffic Reports',
#  'gwere': 'Routine Weather Reports',
#  'gspo': 'Sports',
#  'gaero': 'Aero/Air Sports',
#  'gamer': 'American Football',
#  'gangl': 'Angling',
#  'gaqua': 'Aquatics/Water Sports',
#  'growi': 'Rowing',
#  'gsurf': 'Surfing',
#  'gswim': 'Swimming',
#  'gyach': 'Yachting',
#  'garch': 'Archery',
#  'gathl': 'Athletics',
#  'gmara': 'Marathon',
#  'gozftl': 'Australian Rules Football',
#  'gbadm': 'Badminton',
#  'gbase': 'Baseball',
#  'gbask': 'Basketball',
#  'gbill': 'Billiards/Snooker/Pool',
#  'gbowl': 'Bowls/Petanque',
#  'gclimb': 'Climbing',
#  'gclfo': 'College Sports',
#  'gcombt': 'Combat Sports',
#  'gboxi': 'Boxing',
#  'gjudo': 'Judo',
#  'gkara': 'Karate',
#  'gcric': 'Cricket',
#  'gcycl': 'Cycling',
#  'gdance': 'Dance Sport',
#  'gdart': 'Darts',
#  'gdop': 'Doping in Sports',
#  'gelspo': 'Electronic Sports',
#  'geque': 'Equestrian Sports',
#  'ghors': 'Horse Racing',
#  'gpolo': 'Polo',
#  'gxspo': 'Extreme Sports',
#  'ghock': 'Field Hockey',
#  'gglspo': 'Gaelic Sports',
#  'ggolf': 'Golf',
#  'ggrey': 'Greyhound Racing',
#  'ggymn': 'Gymnastics',
#  'ghand': 'Handball',
#  'ghunt': 'Hunting',
#  'gpelo': 'Jai Alai (Pelota)',
#  'glacr': 'Lacrosse',
#  'gchess': 'Mind Sports',
#  'gmode': 'Modern Pentathlon',
#  'gmoto': 'Motor Sports',
#  'gmora': 'Motor Racing',
#  'gnasc': 'Nascar',
#  'gmocy': 'Motorcycling',
#  'grall': 'Rallying',
#  'gnet': 'Netball',
#  'goly': 'Olympics',
#  'gorie': 'Orienteering',
#  'gpara': 'Para-sports',
#  'grodeo': 'Rodeo',
#  'grugl': 'Rugby League',
#  'grugu': 'Rugby Union',
#  'gshoo': 'Shooting Sports',
#  'gsocc': 'Soccer',
#  'gsoft': 'Softball',
#  'gsebi': 'Sports Event Bidding',
#  'gsqua': 'Squash',
#  'gweig': 'Strength Sports',
#  'gtabt': 'Table Tennis',
#  'gtenn': 'Tennis',
#  'gtenp': 'Tenpin Bowling',
#  'gtria': 'Triathlon',
#  'gvoll': 'Volleyball',
#  'gwint': 'Winter Sports',
#  'galps': 'Alpine Skiing',
#  'gccski': 'Cross-country Skiing',
#  'giceh': 'Ice Hockey',
#  'gsno': 'Snowboarding',
#  'glist': 'TV/Radio Listings',
#  'nrmf': 'Routine Market/Financial News',
#  'nstacs': 'Statistics',
#  'nsur': 'Surveys/Polls',
#  'ntab': 'Tables',
#  'ntra': 'Transcripts',
#  'ccat': 'Corporate/Industrial News',
#  'c1521': "Analysts' Comments/Recommendations",
#  'c34': 'Anti-Competition Issues',
#  'cprpr': 'Predatory Pricing',
#  'cprf': 'Price Fixing',
#  'cprgog': 'Price Gouging',
#  'cbrec': 'Business Resilience/Continuity',
#  'cdinn': 'Business/Disruptive Innovation',
#  'c24': 'Capacity/Facilities',
#  'cautm': 'Automation',
#  'cprdcl': 'Facility Closures',
#  'cprdop': 'Facility Openings',
#  'cnatrd': 'Natural Reserves/Resources Discovery',
#  'c315': 'Conferences/Exhibitions',
#  'c33': 'Contracts/Orders',
#  'ccnttd': 'Contract Tenders',
#  'c332': 'Government Contracts/Orders',
#  'c331': 'Defense Contracts',
#  'c333': 'Non-Government Contracts/Orders',
#  'cdagr': 'Distribution Agreements',
#  'c335': 'Franchises',
#  'c334': 'Licensing Agreements',
#  'coutsc': 'Outsourcing',
#  'cactio': 'Corporate Actions',
#  'c16': 'Bankruptcy',
#  'cbro': 'Bankruptcy Reorganization',
#  'cdip': 'Bankruptcy Financing',
#  'cbrro': 'Bankruptcy-Related Rights Offering',
#  'cclass': 'Class Action Lawsuits',
#  'c172': 'Corporate Debt Instruments',
#  'cmabs': 'Asset Backed Securities',
#  'c174': 'Corporate Credit Ratings',
#  'ceurob': 'Eurobonds',
#  'cjunk': 'High-yield Corporate Bonds',
#  'cmezz': 'Mezzanine Financing',
#  'c1512': 'Dividends',
#  'c18': 'Ownership Changes',
#  'c181': 'Acquisitions/Mergers/Shareholdings',
#  'cacqu': 'Acquisitions/Mergers',
#  'clbo': 'Leveraged Buyouts',
#  'cmbo': 'Management Buyouts',
#  'cmerg': 'Mergers',
#  'cdirdl': 'Insider Stock Sales/Purchases',
#  'cintrf': 'Insider Transaction Filings',
#  'c183': 'Privatizations/Nationalizations',
#  'cshbuy': 'Share Buybacks/Redemptions',
#  'ctendo': 'Tender Offers',
#  'cdiv': 'Divestments',
#  'cspin': 'Demergers',
#  'c184': 'Joint Ventures/Consortia',
#  'cliqui': 'Liquidation',
#  'c182': 'Physical Asset Transactions',
#  'cemdo': 'Eminent Domain',
#  'cscplo': 'Secondary Offerings',
#  'c171': 'Share Capital',
#  'c1711': 'Initial Public Offerings',
#  'crecap': 'Recapitalization',
#  'c1712': 'Shareholder Rights Plans',
#  'cstksp': 'Stock Splits/Bonus Issues',
#  'crevss': 'Reverse Stock Splits',
#  'cstdr': 'Stock Trading Disruptions',
#  'cstre': 'Stock Trading Resumptions',
#  'cscev': 'Unscheduled Material Event Filings',
#  'ccawrd': 'Corporate Awards',
#  'c02': 'Corporate Changes',
#  'ccname': 'Corporate Name Changes',
#  'chqr': 'Headquarters Opening/Relocation',
#  'cncc': 'New Companies Creation',
#  'coffs': 'Production/Services Relocation',
#  'cdelis': 'Stock Delistings',
#  'c14': 'Stock Listings',
#  'c12': 'Corporate Crime/Legal Action',
#  'cinesp': 'Industrial/Corporate Espionage',
#  'crbrea': 'Regulatory Breach',
#  'gsfra': 'Securities Fraud',
#  'cinsdl': 'Insider Dealing',
#  'gponz': 'Ponzi/Pyramid Scheme',
#  'coocs': 'Settlements/Out-of-Court Agreements',
#  'cdued': 'Corporate Due Diligence',
#  'ccfd': 'Corporate Financial Difficulty',
#  'cfdst': 'Distressed Debt',
#  'c17': 'Corporate Funding',
#  'cwarr': 'Corporate Equity Derivatives',
#  'ccrow': 'Crowdfunding',
#  'c173': 'Financing Agreements',
#  'croufi': 'Funding Rounds',
#  'cseedr': 'Seed/Pre-seed Funding',
#  'cpfund': 'Series Funding',
#  'clever': 'Leveraged Loans',
#  'cprpla': 'Private Placements',
#  'csble': 'Small Business Lending',
#  'csbsup': 'Small Business Start-up Capital',
#  'c11': 'Corporate Strategy/Planning',
#  'ccapex': 'Capital Expenditure',
#  'ccpint': 'Competitive Intelligence',
#  'chedge': 'Corporate Hedging',
#  'ceffic': 'Corporate Organizational Restructuring',
#  'ciexp': 'International Expansion',
#  'cdbus': 'Digitalization',
#  'cesg': 'Environmental/Social/Governance',
#  'cenvire': 'Corporate Environmental Responsibility',
#  'cemis': 'Emissions',
#  'cprods': 'Product Sustainability',
#  'ccpgvn': 'Corporate Governance',
#  'cintau': 'Corporate Audit/Internal Control',
#  'cactsh': 'Shareholder Activism',
#  'cprox': 'Proxy Fight',
#  'ccsr': 'Corporate Social Responsibility',
#  'cesgr': 'ESG Reports',
#  'c15': 'Financial Performance',
#  'c151': 'Earnings',
#  'canref': 'Annual Report Filings',
#  'c1514': 'Earnings Surprises',
#  'cqref': 'Quarterly Report Filings',
#  'c1513': 'Sales Figures',
#  'c152': 'Earnings Projections',
#  'cprofi': 'Profit Warnings',
#  'c1522': 'Share Price Movement/Disruptions',
#  'c25': 'Information Technology',
#  'cgymtr': 'Intellectual Property Rights',
#  'c134': 'Copyright',
#  'cinprp': 'Industrial Property Rights',
#  'c133': 'Patents',
#  'ctmark': 'Trademarks',
#  'cknowm': 'Knowledge/Information Management',
#  'cdatam': 'Data Mining',
#  'cdataw': 'Data Warehousing',
#  'c41': 'Management',
#  'c1511': 'Annual/Shareholder/Board Meetings',
#  'cbestp': 'Best Practice',
#  'cboard': 'Board of Directors',
#  'cexecp': 'Executive Pay',
#  'c411': 'Management Moves',
#  'cmmm': 'Middle/Lower Management',
#  'cslmc': 'Senior Level Management',
#  'cfmex': 'Women Executives',
#  'cdom': 'Markets/Marketing',
#  'c312': 'Corporate/Industry Exports',
#  'c311': 'Corporate/Industry Imports',
#  'ciprof': 'Industry Profiles',
#  'c313': 'Market Share',
#  'c31': 'Marketing',
#  'c32': 'Advertising',
#  'cadsp': 'Advertising Spending',
#  'cbrand': 'Branding',
#  'cbramb': 'Brand Ambassadorship',
#  'cgenpr': 'White Labeling',
#  'cbuyl': 'Buy Local Campaigns/Cash Mobs',
#  'ccspon': 'Corporate Sponsorship',
#  'ccrm': 'Customer Relationship Management',
#  'ccexpi': 'Customer Experience',
#  'ccrly': 'Customer Retention/Loyalty',
#  'cmarkr': 'Market Research',
#  'c3141': 'Sales Promotions',
#  'csmad': 'Social Media Marketing/Advertising',
#  'c314': 'Prices',
#  'cusags': 'Usage/Consumption Statistics',
#  'cminor': 'Minority-owned Businesses',
#  'cpartn': 'Partnerships/Collaborations',
#  'cpripu': 'Government-Business Partnerships',
#  'cexpro': 'Products/Services',
#  'c22': 'New Products/Services',
#  'ctrial': 'New Product/Service Testing',
#  'cappro': 'Product/Service Approvals',
#  'c21': 'Output/Production',
#  'cpshrt': 'Product Shortage',
#  'cpstoc': 'Product Stockpile',
#  'c26': 'Product/Consumer Safety',
#  'crecal': 'Product Recalls',
#  'cpsrdi': 'Product/Service Disruptions',
#  'c01': 'Profiles of Companies',
#  'c13': 'Regulation/Government Policy',
#  'ccptax': 'Corporate Taxation',
#  'cdereg': 'Deregulation',
#  'c341': 'Government Aid/Grants',
#  'cnetn': 'Network Neutrality',
#  'c131': 'Regulatory Bodies',
#  'c132': 'Standards/Standardization',
#  'c23': 'Research/Development',
#  'cgvfil': 'Securities Filings',
#  'cproxf': 'Proxy Statement Filings',
#  'csreg': 'Securities Registration/Deregistration Filings',
#  'csmlbs': 'Small/Medium Businesses',
#  'centrp': 'Entrepreneurs/Startups',
#  'csbnew': 'Starting a Business',
#  'c42': 'Staff/Personnel',
#  'cb2e': 'Business-to-Employee (B2E)',
#  'cemret': 'Employee Retention',
#  'cemptd': 'Employee Training/Development',
#  'cmisco': 'Gross Misconduct/Malpractice',
#  'clabdi': 'Labor Disputes',
#  'credun': 'Lay-offs/Redundancies',
#  'crecrt': 'Recruitment',
#  'cwrkpa': 'Workers Pay',
#  'cempbn': 'Employee Benefits',
#  'cwkdis': 'Workplace Abuse',
#  'cwkdiv': 'Workplace Diversity',
#  'coccsh': 'Workplace Safety/Occupational Health',
#  'cscm': 'Supply Chain',
#  'cwmob': 'Women-owned Businesses',
#  'ecat': 'Economic News',
#  'e11': 'Economic Performance/Indicators',
#  'e1110': 'Agricultural Production Figures',
#  'ebklnd': 'Bank Loan Data',
#  'e1108': 'Budget Figures',
#  'e1113': 'Business Inventory Figures',
#  'e1117': 'Business/Economic Sentiment Data',
#  'e1112': 'Capacity Utilization Figures',
#  'e1123': 'Car Registration/Sales Figures',
#  'e1125': 'Composite Economic Indicator Indices',
#  'e1105': 'Consumer Sentiment Figures',
#  'e1106': 'Consumer Spending Figures',
#  'e1124': 'Corporate Bankruptcy Figures',
#  'e1101': 'Economic Growth/Recession',
#  'e1115': 'Employment Cost/Productivity Figures',
#  'e1116': 'Employment/Unemployment Figures',
#  'ejobcl': 'Jobless Claims',
#  'e1114': 'Factory/Manufactured Goods Orders',
#  'ebeige': 'Federal Reserve Survey Data',
#  'efodeb': 'Foreign Debt',
#  'e1111': 'Industrial Production Figures',
#  'e1103': 'Inflation Figures/Price Indices',
#  'ecpin': 'Consumer Price Index',
#  'eppin': 'Producer/Wholesale Price Index',
#  'e1102': 'Money Supply Figures',
#  'e1122': 'Mortgage Application/Refinancing Figures',
#  'e1104': 'Personal Income/Average Earnings',
#  'epmi': 'Purchasing Managers Index',
#  'ereal': 'Real Estate Markets',
#  'ebpmt': 'Building Permit Figures',
#  'ecfig': 'Construction Figures/Output',
#  'e1121': 'Home Sales/Housing Affordability Figures',
#  'emhpr': 'Housing Prices Figures',
#  'ehsal': 'Housing Sales Figures',
#  'e1120': 'Housing Starts',
#  'e1119': 'Reserve Assets Figures',
#  'e1107': 'Retail Sales Figures',
#  'eserv': 'Services Sector Figures',
#  'e1118': 'Trade Figures',
#  'eblpy': 'Balance of Payments/Current Account',
#  'ewhsl': 'Wholesale Sales Figures',
#  'eeczon': 'Economic Zones',
#  'e52': 'Eurozone Data/Policies',
#  'e21': 'Government Finance',
#  'e212': 'Government Borrowing',
#  'e214': 'Subnational Government Borrowing',
#  'e211': 'Government Budget/Taxation',
#  'e2111': 'Direct Taxation',
#  'ecgtax': 'Capital Gains Tax',
#  'eitax': 'Income Tax',
#  'epaytx': 'Payroll Taxes',
#  'eestax': 'Property Taxes',
#  'e2112': 'Indirect Taxation',
#  'estax': 'Sales Tax',
#  'e213': 'Subnational Government Budget/Taxation',
#  'e12': 'Monetary Policy',
#  'ecbdc': 'Central Bank Digital Currencies',
#  'e1201': 'Central Bank Intervention',
#  'e1202': 'Interest Rates',
#  'effund': 'Interbank Rate',
#  'e51': 'Trade/External Payments',
#  'e511': 'Capital Movements/Invisible Trade',
#  'efdi': 'Foreign Direct Investment',
#  'efairt': 'Fair Trade',
#  'e512': 'Physical Trade',
#  'gtrade': 'Trade Barriers/Restrictions',
#  'gtwar': 'Trade Wars',
#  'gcat': 'Political/General News',
#  'ganmtk': 'Animal Attacks',
#  'gdoga': 'Dog Attacks',
#  'gent': 'Arts/Entertainment',
#  'gart': 'Art',
#  'garchi': 'Architecture',
#  'gartau': 'Art Collecting/Sales',
#  'gcoart': 'Contemporary Art',
#  'gdesg': 'Fashion Design',
#  'gmdart': 'Modernist/Postmodernist Art',
#  'gphot': 'Photography',
#  'gbook': 'Books',
#  'gdabal': 'Dance/Ballet',
#  'gfesti': 'Festivals',
#  'gcagm': 'Games',
#  'gmovie': 'Movies',
#  'ganimf': 'Animated Films',
#  'gbolly': 'Bollywood/Indian Films',
#  'gindie': 'Independent Films',
#  'gmusic': 'Music',
#  'gconce': 'Concerts',
#  'gmusls': 'Musicals',
#  'gopera': 'Opera',
#  'gtvrad': 'Television/Radio',
#  'gtheat': 'Theater',
#  'gaward': 'Awards',
#  'gcrim': 'Crime/Legal Action',
#  'gassa': 'Assault',
#  'gtheft': 'Burglary/Theft',
#  'gmovet': 'Motor Vehicle Theft',
#  'grobb': 'Robbery',
#  'gshop': 'Shoplifting',
#  'gchlab': 'Child Abuse',
#  'gorgnz': 'Criminal Enterprises',
#  'ggangs': 'Gangs',
#  'ghack': 'Cybercrime/Hacking',
#  'gsecbr': 'Data Security Breaches',
#  'gdpir': 'Digital Piracy',
#  'gcvir': 'Malware',
#  'gdeath': 'Death Penalty/Capital Punishment',
#  'glibel': 'Defamation',
#  'gdomv': 'Domestic Violence',
#  'genvcr': 'Environmental Crime',
#  'giwild': 'Illegal Wildlife Trade',
#  'gfinc': 'Financial Crime',
#  'gcfra': 'Check Fraud',
#  'gcorrp': 'Corruption',
#  'gbrib': 'Bribery',
#  'gccfra': 'Credit Card Fraud',
#  'gemblz': 'Embezzlement',
#  'gext': 'Extortion/Blackmail',
#  'gifra': 'Insurance Fraud',
#  'gdtcsh': 'Money Laundering',
#  'gmofra': 'Mortgage Fraud',
#  'gteva': 'Tax Fraud',
#  'gtfin': 'Terrorism Financing',
#  'gwefr': 'Welfare/Benefit Fraud',
#  'gfraud': 'Fraud',
#  'gcount': 'Counterfeit/Forgery',
#  'gmfra': 'Healthcare Fraud',
#  'gident': 'Identity Theft',
#  'gscam': 'Phone/Online Scams',
#  'ghara': 'Harassment',
#  'ghate': 'Hate Crime',
#  'ghijk': 'Hijacking/Piracy',
#  'gmurd': 'Homicides',
#  'gmssh': 'Rampage/Serial Killings',
#  'gillgb': 'Illegal Gambling',
#  'gillim': 'Illegal Immigration',
#  'gjuri': 'Juries',
#  'gkdnap': 'Kidnapping/Abduction',
#  'gprob': 'Probation/Home Detention',
#  'grape': 'Sex Crimes',
#  'gterr': 'Terrorism',
#  'gtortu': 'Torture',
#  'gtrff': 'Traffic Violations',
#  'gtraff': 'Trafficking/Smuggling',
#  'gdrug': 'Drug Trafficking/Dealing',
#  'ghutrk': 'Human Trafficking',
#  'gvand': 'Vandalism/Trespass',
#  'garson': 'Arson',
#  'gviwom': 'Violence Against Women',
#  'gwar': 'War Crimes',
#  'gwhis': 'Whistleblowers',
#  'gwirt': 'Wiretapping/Electronic Eavesdropping',
#  'gwitn': 'Witness Tampering',
#  'gdis': 'Disasters/Accidents',
#  'gblac': 'Blackouts',
#  'gexplo': 'Building Fires/Explosions/Collapses',
#  'gntdis': 'Natural Disasters',
#  'gdroug': 'Drought',
#  'gflood': 'Floods/Tidal Waves',
#  'gtsun': 'Tsunamis',
#  'gearth': 'Geological Disasters',
#  'gethqk': 'Earthquakes',
#  'gaval': 'Snow Avalanches',
#  'ghurr': 'Storms',
#  'gblizz': 'Blizzards',
#  'ghrrc': 'Hurricanes/Typhoons',
#  'gtor': 'Tornadoes',
#  'gbush': 'Wildfires',
#  'gnbfir': 'Nonbuilding Structure Fires/Explosions/Collapses',
#  'gtox': 'Toxic Leaks',
#  'gnuca': 'Nuclear Accidents',
#  'gtacc': 'Transport Accidents',
#  'gaira': 'Aviation Accidents',
#  'gedu': 'Education',
#  'gcntsu': 'Continuing Education',
#  'gelear': 'E-learning',
#  'glit': 'Literacy/Illiteracy',
#  'gpres': 'Preschool',
#  'gprive': 'Private Education',
#  'gschol': 'Scholarships/Educational Grants',
#  'gscho': 'School',
#  'gneeds': 'Special Needs Education',
#  'guni': 'University/College',
#  'gedpla': 'Higher Education Costs',
#  'gsloan': 'Student Loans',
#  'gfake': 'Fake News Phenomenon',
#  'gfire': 'Fire/Rescue Services',
#  'gglobe': 'Global/World Issues',
#  'gclimt': 'Climate Change',
#  'gcoseq': 'Carbon Sequestration',
#  'gglblz': 'Globalization',
#  'ghea': 'Health',
#  'gadr': 'Adverse Drug Reactions',
#  'gahea': 'Animal Health',
#  'gavflu': 'Animal Influenza',
#  'gbse': 'Prion Diseases (Animals)',
#  'ggroup': 'Demographic Health',
#  'gghea': 'Geriatric Health',
#  'gihea': 'Infant/Child/Teenage Health',
#  'gmhea': "Men's Health",
#  'gwhea': "Women's Health",
#  'gbreac': 'Breast Cancer',
#  'gasbst': 'Environmental Health',
#  'gainf': 'Animal/Insect Infestations',
#  'gpfas': 'PFAS Pollution',
#  'gtoxal': 'Toxic Algae',
#  'gbirtc': 'Family Planning',
#  'gmed': 'Medical Conditions',
#  'gall': 'Allergies',
#  'gfall': 'Food Allergies',
#  'gartt': 'Arthritis/Rheumatic Conditions',
#  'gautim': 'Autoimmune Diseases',
#  'gmltps': 'Multiple Sclerosis',
#  'gcancr': 'Cancer',
#  'gleuk': 'Blood Cancer',
#  'glivc': 'Gastrointestinal Cancer',
#  'glungc': 'Respiratory Tract Cancer',
#  'gskinc': 'Skin Cancer',
#  'gcard': 'Cardiovascular Conditions',
#  'ghigh': 'Hypertension/High Blood Pressure',
#  'gstrok': 'Stroke',
#  'gtooth': 'Dental Conditions',
#  'gdias': 'Diabetes',
#  'ghear': 'Ear/Hearing Conditions',
#  'gepil': 'Episodic/Paroxysmal Disorders',
#  'ginsom': 'Sleep Disorders',
#  'gblind': 'Eye Conditions',
#  'ghemo': 'Genetic Disorders',
#  'gspox': 'Infectious Diseases',
#  'ghepat': 'Hepatitis',
#  'gswine': 'Human Influenza',
#  'gchlra': 'Infectious Foodborne/Waterborne Diseases',
#  'gecol': 'E. Coli Infections',
#  'gmenig': 'Meningitis',
#  'gsars': 'Novel Coronaviruses',
#  'gout': 'Outbreaks/Epidemics',
#  'gstd': 'Sexually Transmitted Diseases',
#  'ghiv': 'AIDS/HIV',
#  'gsuper': 'Superbugs',
#  'gtub': 'Tuberculosis',
#  'gmosq': 'Vector-borne/Zoonotic Diseases',
#  'gmala': 'Mosquito-borne Diseases',
#  'gment': 'Mental Disorders',
#  'gphob': 'Anxiety Disorders',
#  'gaddic': 'Behavioral Addictions/Obsessions',
#  'gdeme': 'Dementia',
#  'galz': "Alzheimer's Disease",
#  'geat': 'Eating Disorders',
#  'gdepr': 'Mood Disorders',
#  'gadhd': 'Neurodevelopmental Disorders',
#  'gauti': 'Autism Spectrum Disorders',
#  'gpark': 'Movement Disorders',
#  'gneuro': 'Neurodegenerative Diseases',
#  'gobes': 'Obesity',
#  'gpois': 'Poisoning',
#  'gcold': 'Respiratory Tract Diseases',
#  'gastma': 'Asthma',
#  'gstres': 'Stress-related Conditions',
#  'gcrese': 'Medical Research',
#  'gtrea': 'Medical Treatments/Procedures',
#  'gabor': 'Abortion',
#  'galtm': 'Alternative Medicine/Treatments',
#  'gblood': 'Blood Donations/Transfusions',
#  'gchemo': 'Chemotherapy/Radiotherapy/Immunotherapy',
#  'gdent': 'Dentistry',
#  'gdial': 'Dialysis',
#  'gcell': 'Gene/Cell Therapy',
#  'gimmu': 'Immunizations',
#  'gpsych': 'Mental Health Therapies',
#  'gorga': 'Organ/Tissue Transplants',
#  'gprepi': 'Prosthetic Replacements/Implants',
#  'grdly': 'Radiology',
#  'gnutr': 'Nutrition',
#  'gfitn': 'Physical/Mental Fitness',
#  'gwelss': 'Weight Management',
#  'gsexu': 'Sexuality',
#  'gteleh': 'Telemedicine',
#  'ghnwi': 'High Net Worth Individuals',
#  'gjob': 'Labor Issues',
#  'gcrpln': 'Career Planning/Management',
#  'gjsear': 'Job Search',
#  'gmini': 'Minimum/Living Wage',
#  'gbal': 'Work-Life Balance',
#  'gtcom': 'Telecommuting',
#  'glife': 'Living/Lifestyle',
#  'gbeau': 'Beauty',
#  'gcar': 'Cars',
#  'gcele': 'Celebrities',
#  'gfas': 'Fashion',
#  'gfasw': 'Fashion Shows/Events',
#  'gfod': 'Food/Drink',
#  'gwbs': 'Wine/Beer/Spirits',
#  'ggard': 'Home Gardening/Landscaping',
#  'ghimp': 'Home Improvements',
#  'gengy': 'Energy Efficient Home Improvements',
#  'glux': 'Luxury Homes/Estates',
#  'gparen': 'Parenting/Parenthood',
#  'gptech': 'Personal Technology',
#  'gpreti': 'Post-retirement',
#  'grelad': 'Relationships',
#  'gweb': 'Social Media',
#  'godd': 'Strange But True',
#  'gtour': 'Travel',
#  'gcrui': 'Cruises',
#  'gluxtr': 'Luxury Travel',
#  'goveto': 'Overtourism',
#  'gtdeal': 'Travel Deals/Packages',
#  'gcns': 'National/Public Security',
#  'gdef': 'Armed Forces',
#  'gairf': 'Air Force',
#  'garmy': 'Army',
#  'gmilac': 'Military Aid/Cooperation',
#  'gvio': 'Military Operations',
#  'gcoup': 'Armed Rebellion',
#  'gnavy': 'Navy',
#  'gweap': 'Weapons Programs',
#  'gnuclw': 'Nuclear Weapons Programs',
#  'gcivds': 'Civil Unrest',
#  'gspy': 'Espionage',
#  'ghome': 'Law Enforcement',
#  'gpobru': 'Police Brutality',
#  'gpris': 'Prisons/Prisoners',
#  'gsec': 'State Security Measures/Policies',
#  'genv': 'Natural Environment',
#  'gforst': 'Deforestation',
#  'gqual': 'Environmental Pollution',
#  'gairp': 'Air Pollution',
#  'gplpol': 'Plastic Pollution',
#  'gsoilp': 'Soil Pollution',
#  'gwtpol': 'Water Pollution',
#  'gnatcn': 'Environmental Protection',
#  'gnrsca': 'Natural Resource Scarcity',
#  'gplant': 'Plant Health',
#  'gsust': 'Sustainable Development/Sustainability',
#  'genee': 'Energy Efficiency',
#  'gfuel': 'Fuel Efficiency',
#  'gpersf': 'Personal Finance',
#  'gasset': 'Asset Allocation',
#  'gsell': 'Buying/Selling a Home',
#  'gspend': 'Consumer Spending/Budgeting',
#  'gdeals': 'Consumer Deals',
#  'gestat': 'Estate Planning',
#  'gfam': 'Family Finance',
#  'gfnpl': 'Financial Advisors',
#  'cfore': 'Foreclosures',
#  'ghplan': 'Health Planning',
#  'geldcr': 'Long-term Care Costs',
#  'gmort': 'Mortgage Planning/Trends',
#  'grefi': 'Mortgage Refinancing',
#  'gpbnkr': 'Personal Bankruptcy',
#  'gpcred': 'Personal Credit Score',
#  'gpersi': 'Personal Investments',
#  'gcoliv': 'Collectible Investments',
#  'gfxiin': 'Fixed Income Investing',
#  'ginvbn': 'Personal Investments in Bonds',
#  'giidea': 'Investment Ideas/Investor Education',
#  'givsto': 'Personal Investments in Stocks',
#  'gretir': 'Retirement Planning',
#  'gira': 'Individual Retirement Accounts',
#  'gtaxst': 'Tax Strategies',
#  'gpir': 'Politics/International Relations',
#  'gpol': 'Domestic Politics',
#  'gvote': 'Elections',
#  'gengsc': 'Energy Security',
#  'gexpol': 'Extremist Politics',
#  'ghonl': 'Honours List/Decorations',
#  'gimpch': 'Impeachment',
#  'gpapp': 'Political Appointments/Terminations',
#  'gpinq': 'Public Inquiries',
#  'greg': 'Regional Politics',
#  'gplan': 'Urban/Rural Planning',
#  'gland': 'Land Use',
#  'gsmart': 'Smart City Development',
#  'gegov': 'e-Government',
#  'gimm': 'Human Migration',
#  'grefu': 'Refugees/Asylum Seekers',
#  'gdip': 'International Relations',
#  'gdev': 'Development/Humanitarian Aid',
#  'gesanc': 'International Sanctions',
#  'gdatap': 'Privacy Issues/Information Security',
#  'greest': 'Real Estate/Property',
#  'grent': 'Renting/Letting',
#  'grisk': 'Risk News',
#  'groyal': 'Royal Families',
#  'gsci': 'Sciences/Humanities',
#  'gantpy': 'Anthropology',
#  'garlgy': 'Archaeology',
#  'gastro': 'Astronomy',
#  'gbiol': 'Biology',
#  'gbiot': 'Biotechnology',
#  'gchem': 'Chemistry',
#  'gcsci': 'Computer Science',
#  'gaiml': 'Artificial Intelligence/Machine Learning',
#  'ggenai': 'Generative AI',
#  'ggeo': 'Geography/Geology',
#  'ghist': 'History',
#  'gmath': 'Mathematics',
#  'gnano': 'Nanotechnology',
#  'gocea': 'Oceanography',
#  'gpaleo': 'Paleontology',
#  'gphys': 'Physics',
#  'gpsyl': 'Psychology',
#  'grobo': 'Robotics',
#  'gsocl': 'Sociology',
#  'gcom': 'Society/Community',
#  'gcha': 'Charities/Volunteering',
#  'gcltre': 'Cultural Heritage',
#  'gdemog': 'Demographics',
#  'gdgdv': 'Digital Divide',
#  'gfdsec': 'Food/Drinking Water Security',
#  'gcoho': 'Generational Cohorts',
#  'ghum': 'Human Rights/Civil Liberties',
#  'gcens': 'Censorship',
#  'gchlbr': 'Child Labor',
#  'gdcri': 'Discrimination',
#  'gaffm': 'Affirmative Action',
#  'gaged': 'Age Discrimination',
#  'gdisab': 'Disability Discrimination',
#  'gracm': 'Racism/Xenophobia',
#  'greldi': 'Religious Discrimination',
#  'gsexd': 'Sex Discrimination',
#  'gfrcl': 'Forced Labor',
#  'gwori': 'Gender Equality',
#  'glgbt': 'LGBT Rights',
#  'ggaym': 'Same-Sex Marriage/Civil Union',
#  'gideol': 'Ideology',
#  'gwedd': 'Marriage/Divorce',
#  'grel': 'Religion',
#  'gchris': 'Christianity',
#  'gislam': 'Islam',
#  'gsoc': 'Social Issues',
#  'garig': 'Animal Rights',
#  'gcgamb': 'Compulsive Gambling',
#  'gabus': 'Drug/Substance Use/Abuse',
#  'galcm': 'Alcoholism',
#  'gcoca': 'Cocaine Use/Abuse',
#  'gheroi': 'Heroin/Illegal Opioid Use/Abuse',
#  'gmarij': 'Marijuana Use/Abuse',
#  'gmam': 'Medication Abuse/Misuse',
#  'gmetha': 'Methamphetamine Use/Abuse',
#  'gsmok': 'Smoking',
#  'gethic': 'Ethical Issues',
#  'geuth': 'Euthanasia',
#  'gethm': 'Ethnic Minorities',
#  'gfost': 'Fostering/Adoption',
#  'ggunc': 'Gun Control',
#  'ghouse': 'Housing Issues',
#  'gafho': 'Affordable/Social Housing',
#  'ghomel': 'Homelessness',
#  'gpolyg': 'Polygamy',
#  'gporn': 'Pornography',
#  'gpov': 'Poverty',
#  'gprost': 'Prostitution',
#  'gsuic': 'Suicide',
#  'gspam': 'Spamming',
#  'gwelf': 'Welfare/Social Services',
#  'gspace': 'Space',
#  'gsjunk': 'Space Debris',
#  'gtrans': 'Transport',
#  'gwea': 'Weather',
#  'redit': 'Selection of Top Stories/Trends/Analysis',
#  'reqr': 'Suggested Reading – Industry News',
#  'reqrac': 'Suggested Reading – Accounting/Consulting',
#  'reqrap': 'Suggested Reading – Advertising/Public Relations/Marketing',
#  'reqrad': 'Suggested Reading – Aerospace/Defense',
#  'reqraf': 'Suggested Reading – Agriculture/Forestry',
#  'reqrai': 'Suggested Reading – Airlines',
#  'reqrau': 'Suggested Reading – Automobiles',
#  'reqrbc': 'Suggested Reading – Banking/Credit',
#  'reqbio': 'Suggested Reading – Biotechnology',
#  'reqbcs': 'Suggested Reading – Business/Consumer Services',
#  'reqrch': 'Suggested Reading – Chemicals',
#  'reqrct': 'Suggested Reading – Clothing/Textiles',
#  'reqrcm': 'Suggested Reading – Computers',
#  'reqrcr': 'Suggested Reading – Construction/Real Estate',
#  'reqrcp': 'Suggested Reading – Consumer Products',
#  'reqren': 'Suggested Reading – Energy',
#  'reqevr': 'Suggested Reading – Environment/Waste Management',
#  'reqrfb': 'Suggested Reading – Food/Beverages/Tobacco',
#  'reqrhc': 'Suggested Reading – Healthcare',
#  'reqrhr': 'Suggested Reading – Hotels/Restaurants/Casinos',
#  'reqrin': 'Suggested Reading – Insurance',
#  'reqrio': 'Suggested Reading – Internet/Online Services',
#  'reqris': 'Suggested Reading – Investing/Securities',
#  'reqlea': 'Suggested Reading – Leisure/Arts',
#  'reqmig': 'Suggested Reading – Machinery/Industrial Goods',
#  'reqrme': 'Suggested Reading – Media',
#  'reqrmm': 'Suggested Reading – Metals/Mining',
#  'reqpap': 'Suggested Reading – Paper/Packaging',
#  'reqrph': 'Suggested Reading – Pharmaceuticals',
#  'reqrre': 'Suggested Reading – Retail',
#  'reqrte': 'Suggested Reading – Telecommunications',
#  'reqrts': 'Suggested Reading – Transportation/Shipping',
#  'ntop': 'Top Wire News'}

# %%
# Transformation de la colonne de codes en liste de significations
df["subjects"] = df["subject_codes"].apply(lambda s: [
    mapping.get(code.strip().lower(), f"[unknown:{code}]")
    for code in str(s).strip(',').split(',')
    if code.strip()
] if isinstance(s, str) else [])

# %%
df['subjects_sep'] = df['subjects'].apply(lambda x: ",".join(x))

# %% [markdown]
# ### Rajouter les liens google drive

# %%
mapping_id = pd.read_csv('sample - Matching articles id drive.csv')

# %%
mapping_id.rename(columns={'Nom du fichier':'nom_fichier', 'ID':'fichier_id'}, inplace=True)

# %%
mapping_id['nom_fichier'] = mapping_id['nom_fichier'].apply(lambda x :x[:-4])

# %%
# 1. Join sur le nom de fichier pour récupérer l'ID Drive
df = df.merge(mapping_id, on="nom_fichier", how="left")

# 2. Construire le lien hypertexte
# Format Drive : https://drive.google.com/file/d/<file_id>/view
df["lien_drive"] = df["fichier_id"].apply(lambda fid: f"https://drive.google.com/file/d/{fid}/view" if pd.notnull(fid) else None)

# %%
df.head()
# Out:
#   source_name                                              title  \
# 0  L'Humanité                                    L’œil de Bobika
# 1  L'Humanité  Claude Ven est décédé le 4 avril à l’âge de 63...
# 2  L'Humanité                                    L’œil de Bobika
# 3  L'Humanité                                      L’œil de Gros
# 4  Libération  Réponse fraternelle à Dominique de Villepin : ...
#
#   publication_date     subject_codes word_count                Dossier  \
# 0       2025-04-14       ,ncat,nhoc,          4  articles_pdf_national
# 1       2025-04-15       ,gcat,gjob,        400  articles_pdf_national
# 2       2025-04-15       ,ncat,nhoc,          4  articles_pdf_national
# 3       2025-04-16       ,ncat,nhoc,          4  articles_pdf_national
# 4       2025-04-15  ,gcat,gpir,gpol,       1180  articles_pdf_national
#
#                   nom_fichier                          publisher_name  \
# 0   LHumanité_1744570903000_0  Société Nouvelle du Journal l'Humanité
# 1   LHumanité_1744657577000_1  Société Nouvelle du Journal l'Humanité
# 2   LHumanité_1744657578000_2  Société Nouvelle du Journal l'Humanité
# 3   LHumanité_1744743866000_3  Société Nouvelle du Journal l'Humanité
# 4  Libération_1744806835000_4                              Libération
#
#   source_code industry_codes section document_type         region_of_origin  \
# 0       HUMAN            NaN     NaN       article      EUR FRA MEDZ WEURZ
# 1       HUMAN            NaN     NaN       article      EUR FRA MEDZ WEURZ
# 2       HUMAN            NaN     NaN       article      EUR FRA MEDZ WEURZ
# 3       HUMAN            NaN     NaN       article      EUR FRA MEDZ WEURZ
# 4      LIBERA            NaN     NaN       article  AFRICA MEDZ MOROC NAFR
#
#                         region_codes                         an  \
# 0         ,eecz,eurz,fra,medz,weurz,  HUMAN00020250413el4e00002
# 1  ,britty,eecz,eurz,fra,medz,weurz,  HUMAN00020250414el4f000rx
# 2         ,eecz,eurz,fra,medz,weurz,  HUMAN00020250414el4f000s9
# 3         ,eecz,eurz,fra,medz,weurz,  HUMAN00020250415el4g000m9
# 4         ,eecz,eurz,fra,medz,weurz,  LIBERA0020250416el4f00001
#
#    ingestion_datetime publication_datetime   modification_date  \
# 0 2025-04-13 19:01:43           2025-04-14 2025-04-14 08:52:40
# 1 2025-04-14 19:06:17           2025-04-15 2025-04-15 07:31:12
# 2 2025-04-14 19:06:18           2025-04-15 2025-04-15 07:33:00
# 3 2025-04-15 19:04:26           2025-04-16 2025-04-16 07:30:33
# 4 2025-04-16 12:33:55           2025-04-15 2025-04-17 07:29:29
#
#   modification_datetime                                       copyright  \
# 0   2025-04-13 19:01:43  Copyright 2025 l'Humanité All Rights Reserved
# 1   2025-04-14 19:06:17  Copyright 2025 l'Humanité All Rights Reserved
# 2   2025-04-14 19:06:18  Copyright 2025 l'Humanité All Rights Reserved
# 3   2025-04-15 19:04:26  Copyright 2025 l'Humanité All Rights Reserved
# 4   2025-04-16 12:33:55                      Copyright 2025 Libération
#
#   language_code dateline byline  \
# 0            fr      NaN    NaN
# 1            fr      NaN    NaN
# 2            fr      NaN    NaN
# 3            fr      NaN    NaN
# 4            fr      NaN    NaN
#
#                                             subjects  \
# 0             [Content Types, Headline-Only Content]
# 1             [Political/General News, Labor Issues]
# 2             [Content Types, Headline-Only Content]
# 3             [Content Types, Headline-Only Content]
# 4  [Political/General News, Politics/Internationa...
#
#                                         subjects_sep  \
# 0                Content Types,Headline-Only Content
# 1                Political/General News,Labor Issues
# 2                Content Types,Headline-Only Content
# 3                Content Types,Headline-Only Content
# 4  Political/General News,Politics/International ...
#
#                           fichier_id  \
# 0  1QQLMoJkwjEs4s3rLJBO_XtyKy5KWeKN4
# 1  1gmFNy4kFjxoNGllm2WhIossCC8mEqLQJ
# 2  1Ln1OlYc77_hehzHNGGYXICF8YRV-eSA2
# 3  1ywiXNKfil14JMUgQbLHG-y224_DH_C2q
# 4  1yhxCtJGV_Y7LG-D8MCRXayAwZ90gC62G
#
#                                           lien_drive
# 0  https://drive.google.com/file/d/1QQLMoJkwjEs4s...
# 1  https://drive.google.com/file/d/1gmFNy4kFjxoNG...
# 2  https://drive.google.com/file/d/1Ln1OlYc77_heh...
# 3  https://drive.google.com/file/d/1ywiXNKfil14JM...
# 4  https://drive.google.com/file/d/1yhxCtJGV_Y7LG...

# %% [markdown]
# ### Export de données

# %%
df.to_csv("export_factiva.csv")

# %% [markdown]
# ### Analyses - Obtenir le top par catégories

# %%
# Étape 1 : aplatir toutes les catégories
all_categories = df['subjects_sep'].dropna().apply(lambda x: [cat.strip() for cat in x.split(',')])

# Étape 2 : compter avec Counter
flat_list = [cat for sublist in all_categories for cat in sublist]
counter = Counter(flat_list)

# Étape 3 : transformer en DataFrame trié
df_counts = pd.DataFrame(counter.items(), columns=['categorie', 'nb_mentions'])
df_counts = df_counts.sort_values(by='nb_mentions', ascending=False).reset_index(drop=True)

print(df_counts)
# Out:
#                             categorie  nb_mentions
# 0              Political/General News        11539
# 1                       Content Types         4669
# 2                     Factiva Filters         4016
# 3    Politics/International Relations         2853
# 4                      [unknown:nfce]         2767
# ..                                ...          ...
# 580                  Geriatric Health            1
# 581                            Squash            1
# 582                        Meningitis            1
# 583                      Orienteering            1
# 584            Bollywood/Indian Films            1
#
# [585 rows x 2 columns]

# %%
df_counts.head(200)
# Out:
#                                           categorie  nb_mentions
# 0                            Political/General News        11539
# 1                                     Content Types         4669
# 2                                   Factiva Filters         4016
# 3                  Politics/International Relations         2853
# 4                                    [unknown:nfce]         2767
# 5                                 Domestic Politics         2623
# 6                              Routine General News         2504
# 7                                 Society/Community         2368
# 8                                Arts/Entertainment         2144
# 9                                            Sports         2067
# 10                        Corporate/Industrial News         1408
# 11                                                          1185
# 12         Selection of Top Stories/Trends/Analysis         1067
# 13                Suggested Reading – Industry News         1067
# 14                                 Living/Lifestyle         1002
# 15                                         Religion          958
# 16                                    Economic News          869
# 17                                 [unknown:nfcpin]          827
# 18                               Crime/Legal Action          684
# 19                                 [unknown:nfcpex]          667
# 20                         National/Public Security          602
# 21                                           Health          552
# 22                                        Risk News          552
# 23                          International Relations          532
# 24                                           Movies          514
# 25                                   [unknown:niwe]          476
# 26                                        Education          473
# 27                                           Soccer          453
# 28                                     Armed Forces          451
# 29                                            Music          411
# 30                              Military Operations          400
# 31                          Trade/External Payments          394
# 32                                           School          383
# 33                      Trade Barriers/Restrictions          375
# 34                                            Books          350
# 35                               Government Finance          342
# 36                               Calendar of Events          337
# 37                       Government Budget/Taxation          327
# 38                                           Images          325
# 39                              Sciences/Humanities          312
# 40                                Regional Politics          309
# 41                               Medical Conditions          301
# 42                                              Art          276
# 43                                     Christianity          271
# 44                                        Elections          258
# 45                              Global/World Issues          253
# 46                                     Labor Issues          239
# 47                                      Rugby Union          233
# 48                                       Food/Drink          227
# 49                            Commentaries/Opinions          223
# 50                              Disasters/Accidents          219
# 51                                Corporate Actions          212
# 52                              Natural Environment          210
# 53                                        Festivals          201
# 54                                 Page One Stories          199
# 55                                Ownership Changes          196
# 56                                       Interviews          189
# 57                                 Television/Radio          185
# 58                            Financial Performance          173
# 59                  Economic Performance/Indicators          168
# 60                                       Management          167
# 61       Suggested Reading – Food/Beverages/Tobacco          155
# 62               Acquisitions/Mergers/Shareholdings          149
# 63                                         Earnings          145
# 64                                          Theater          141
# 65                                   Press Releases          140
# 66                                         Concerts          139
# 67                                          Reviews          139
# 68                                       Editorials          134
# 69                                        Transport          131
# 70                                    Social Issues          124
# 71                                          Cycling          119
# 72                                     Social Media          119
# 73                                  Law Enforcement          112
# 74                                  Staff/Personnel          110
# 75                     Regulation/Government Policy          110
# 76                                          History          109
# 77                                Markets/Marketing          107
# 78                                Natural Disasters          106
# 79                                    Sales Figures           97
# 80                    Medical Treatments/Procedures           97
# 81                                       Basketball           96
# 82                                   Climate Change           92
# 83                                          Weather           92
# 84            Suggested Reading – Consumer Products           91
# 85         Suggested Reading – Investing/Securities           91
# 86                                Prisons/Prisoners           89
# 87      Suggested Reading – Transportation/Shipping           86
# 88                  Suggested Reading – Automobiles           83
# 89                                       Sex Crimes           81
# 90                                       Trade Wars           80
# 91                 Suggested Reading – Leisure/Arts           79
# 92               Suggested Reading – Banking/Credit           79
# 93                                          Fashion           78
# 94           Subnational Government Budget/Taxation           73
# 95                          Senior Level Management           71
# 96                                   Budget Figures           71
# 97                                  Human Migration           71
# 98                        Suggested Reading – Media           70
# 99                                             Cars           65
# 100    Suggested Reading – Construction/Real Estate           64
# 101                    Human Rights/Civil Liberties           62
# 102                             Capacity/Facilities           62
# 103                                Management Moves           62
# 104                                   Combat Sports           61
# 105                              University/College           60
# 106                                  Royal Families           60
# 107                       Economic Growth/Recession           60
# 108                      Suggested Reading – Retail           59
# 109                                Mental Disorders           59
# 110                           Government Aid/Grants           58
# 111                                        Handball           57
# 112                            Acquisitions/Mergers           57
# 113                    Corporate Crime/Legal Action           57
# 114                 Commodity/Financial Market News           57
# 115                           Aquatics/Water Sports           56
# 116                               Products/Services           56
# 117                             Transport Accidents           55
# 118                                       Homicides           54
# 119                         Physical/Mental Fitness           53
# 120                             Infectious Diseases           53
# 121                         Welfare/Social Services           53
# 122                                Weapons Programs           52
# 123                   Suggested Reading – Computers           49
# 124  Suggested Reading – Hotels/Restaurants/Casinos           49
# 125        Artificial Intelligence/Machine Learning           49
# 126                                Computer Science           49
# 127                                       Terrorism           48
# 128                   Suggested Reading – Insurance           46
# 129                                    Motor Sports           46
# 130                                  Bowls/Petanque           46
# 131                                        Olympics           45
# 132                                  Discrimination           44
# 133                           Trafficking/Smuggling           43
# 134                          Personal Announcements           42
# 135                      Suggested Reading – Energy           42
# 136                              Floods/Tidal Waves           42
# 137                                  Burglary/Theft           42
# 138                                           Fraud           41
# 139                             Outbreaks/Epidemics           41
# 140                                          Tennis           40
# 141                                          Awards           40
# 142                         Small/Medium Businesses           40
# 143                                  Labor Disputes           39
# 144    Suggested Reading – Internet/Online Services           39
# 145                                      War Crimes           39
# 146                                         Assault           38
# 147                     Corporate Strategy/Planning           38
# 148                                           Islam           38
# 149                         Environmental Pollution           38
# 150                               Cultural Heritage           37
# 151                               Equestrian Sports           37
# 152           Suggested Reading – Aerospace/Defense           36
# 153                        Drug Trafficking/Dealing           36
# 154                    Blood Donations/Transfusions           35
# 155                            Criminal Enterprises           35
# 156                                          Cancer           34
# 157                           Headline-Only Content           34
# 158                                 Direct Taxation           33
# 159                     Modernist/Postmodernist Art           33
# 160                                       Marketing           33
# 161                           Lay-offs/Redundancies           32
# 162                             Illegal Immigration           32
# 163               Annual/Shareholder/Board Meetings           31
# 164                          Charities/Volunteering           31
# 165                               Private Education           31
# 166                                           Space           31
# 167                           News Agency Materials           31
# 168                                         Hunting           30
# 169             Suggested Reading – Pharmaceuticals           30
# 170                             Hurricanes/Typhoons           30
# 171                                 Financial Crime           30
# 172                                          Storms           30
# 173                            Kidnapping/Abduction           29
# 174                                       Athletics           29
# 175                      High Net Worth Individuals           29
# 176                                        Yachting           29
# 177                           New Products/Services           29
# 178                                            Judo           29
# 179                                 Monetary Policy           27
# 180                            Real Estate/Property           27
# 181                        Nuclear Weapons Programs           27
# 182                         Conferences/Exhibitions           26
# 183                                  Equity Markets           26
# 184                  Vector-borne/Zoonotic Diseases           25
# 185                                    News Digests           25
# 186                                     Photography           25
# 187                                Personal Finance           25
# 188                        Environmental Protection           25
# 189                                     Liquidation           24
# 190                                   Immunizations           24
# 191                                Contracts/Orders           24
# 192                                  Interest Rates           23
# 193                               Headline Listings           23
# 194                                    Motor Racing           23
# 195          Corporate Organizational Restructuring           23
# 196               Suggested Reading – Metals/Mining           23
# 197                     Partnerships/Collaborations           23
# 198                  Corporate Financial Difficulty           22
# 199                          Eurozone Data/Policies           22

# %% [markdown]
# # OLD

# %%
df.head().to_excel('sample.xlsx', index=False)

# %%
nom_fichier = "MlemagazineduMonde_1745578905000_284"
df.query('nom_fichier==@nom_fichier')
# Out:
#                  source_name  \
# 284  M, le magazine du Monde
#
#                                                  title publication_date  \
# 284  pilier de "Top chef", journaliste gastronomiqu...       2025-04-26
#
#                    subject_codes word_count                Dossier  \
# 284  ,gcat,gfod,glife,ncat,nhoc,         21  articles_pdf_national
#
#                               nom_fichier             publisher_name  \
# 284  MlemagazineduMonde_1745578905000_284  Société Editrice du Monde
#
#     source_code industry_codes section document_type     region_of_origin  \
# 284     MONDMAG            NaN   , Une       article  EUR FRA MEDZ WEURZ
#
#                    region_codes                         an  \
# 284  ,eecz,eurz,fra,medz,weurz,  MONDMAG020250425el4q00006
#
#      ingestion_datetime publication_datetime   modification_date  \
# 284 2025-04-25 11:01:45           2025-04-26 2025-04-26 07:31:37
#
#     modification_datetime                                   copyright  \
# 284   2025-04-25 11:01:45  (c) Le Monde. 2025. Tous droits réservés.
#
#     language_code dateline byline
# 284            fr      NaN    NaN

# %%
result = df[df.nom_fichier == "MlemagazineduMonde_1745578905000_284"]

# %%
result
# Out:
#                  source_name  \
# 284  M, le magazine du Monde
#
#                                                  title publication_date  \
# 284  pilier de "Top chef", journaliste gastronomiqu...       2025-04-26
#
#                    subject_codes word_count                Dossier  \
# 284  ,gcat,gfod,glife,ncat,nhoc,         21  articles_pdf_national
#
#                               nom_fichier             publisher_name  \
# 284  MlemagazineduMonde_1745578905000_284  Société Editrice du Monde
#
#     source_code industry_codes section document_type     region_of_origin  \
# 284     MONDMAG            NaN   , Une       article  EUR FRA MEDZ WEURZ
#
#                    region_codes                         an  \
# 284  ,eecz,eurz,fra,medz,weurz,  MONDMAG020250425el4q00006
#
#      ingestion_datetime publication_datetime   modification_date  \
# 284 2025-04-25 11:01:45           2025-04-26 2025-04-26 07:31:37
#
#     modification_datetime                                   copyright  \
# 284   2025-04-25 11:01:45  (c) Le Monde. 2025. Tous droits réservés.
#
#     language_code dateline byline
# 284            fr      NaN    NaN

# %%
result['lien'] = result['nom_fichier'].apply(
    lambda x: f'=HYPERLINK("Article national/{x}.pdf", "{x}.pdf")'
)
# Out:
# C:\Users\Arnaud 1\AppData\Local\Temp\ipykernel_7080\1442908695.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['lien'] = result['nom_fichier'].apply(

# %%
result
# Out:
#                  source_name  \
# 284  M, le magazine du Monde
#
#                                                  title publication_date  \
# 284  pilier de "Top chef", journaliste gastronomiqu...       2025-04-26
#
#                    subject_codes word_count                Dossier  \
# 284  ,gcat,gfod,glife,ncat,nhoc,         21  articles_pdf_national
#
#                               nom_fichier             publisher_name  \
# 284  MlemagazineduMonde_1745578905000_284  Société Editrice du Monde
#
#     source_code industry_codes section document_type     region_of_origin  \
# 284     MONDMAG            NaN   , Une       article  EUR FRA MEDZ WEURZ
#
#                    region_codes                         an  \
# 284  ,eecz,eurz,fra,medz,weurz,  MONDMAG020250425el4q00006
#
#      ingestion_datetime publication_datetime   modification_date  \
# 284 2025-04-25 11:01:45           2025-04-26 2025-04-26 07:31:37
#
#     modification_datetime                                   copyright  \
# 284   2025-04-25 11:01:45  (c) Le Monde. 2025. Tous droits réservés.
#
#     language_code dateline byline  \
# 284            fr      NaN    NaN
#
#                                                   lien
# 284  =HYPERLINK("Article national/MlemagazineduMond...

# %%
result.to_excel("liens_google_sheets.xlsx", index=False)
